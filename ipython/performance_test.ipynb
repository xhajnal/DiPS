# %% [markdown]
# # PERFORMANCE TEST - a part of:  Data-informed parameter synthesis for population pDTMCs, notebook 7/6
#
# This notebook ease the performance test as it contains only neccessary cells for this purpose. The partial results are updated after each run using pickle lib to store a dictionary of the results.
#
# We use synthetic data obtained by simulating respective Markov Chain - D3. You may generate your own dataset (using one of our notebooks - 4/6) or write us an email and we will send you our data_set.
#
# following list variables are used to choose which settings are used:
#
# `alphas`, `n_sampless`, `depths`, `epsilons`, `coverage_threshs`, `populations`, `methods`
#
# and the `sample_size` determines how many times is the refinement procedure run for the same setting
#
# Average time and variance is further computed.
#
# Using empirical information we have decided to set the timeout(TO) equal to 1 hour, as some runs may contain time higher than this threshold we simply did not delete the information once we have obtained it.
#
# We plan to improve this test to automatically skip the run when the time threshold has passed.

# %%
import os,sys,socket

# %%
cwd = os.getcwd()
os.chdir("..")
sys.path.append(os.getcwd())
os.chdir(cwd)

# %%
os.getcwd()

# %%
from src.synthetise import *

# %%
from sympy import Interval

# %%
from src.load import get_f, get_rewards

# %%
agents_quantities = [2,3,5,10]

# %%
start_time = time()
f = get_f("./asyn*[0-9].txt", "prism", True, agents_quantities)
print("  It took", socket.gethostname(), time() - start_time, "seconds to run")

# %%
from src.load import load_pickled_data

# %%
D3 = load_pickled_data("Data_two_param")

# %%
f[2]

# %%
D3[('synchronous_', 2, 100, 0.028502714675268215, 0.03259111103419188)]

# %%
from src.load import create_interval, margin, create_intervals

# %%
create_intervals(0.95, 1500, D3[('synchronous_', 2, 100, 0.028502714675268215, 0.03259111103419188)])

# %%
import pickle

# %%
os.chdir("..")
# os.mkdir("performance_results")
os.chdir("performance_results")

# %%
p_values = sorted([0.028502714675268215, 0.13075717833714784, 0.45223461506339047, 0.6855555397734584, 0.8732745414252937])
q_values = sorted([0.03259111103419188 , 0.29577906622244676, 0.5057623641293089 , 0.8108008054929994, 0.8440550299528644])

alphas = [0.95]
n_sampless = [100,1500,3500]
depths = [12] 
epsilons = [10e-6]
coverage_threshs = [0.95]
populations = agents_quantities
methods = [2,3,4,5]
sample_size = 1
sys.setrecursionlimit(22000)

# %%
results = {}
coverages = {}
averages_and_deviations = {}

# %%
results = pickle.load(open("results.p","rb"))
coverages = pickle.load(open("coverages.p","rb"))
averages_and_deviations = pickle.load(open("averages_and_deviations.p","rb"))

# %%
for i in results.keys():
    print(i)
    print(results[i])
    try:
        print(coverages[i])
    except KeyError:
        del results[i]
    try: 
        print(averages_and_deviations[i])
    except KeyError:
        del results[i]
        del coverages[i]
## Where the values are
# alpha, n_samples, max_depth, min_rect_size, population, algorithm, v_p, v_q

# %%
for i in results.keys():
    print(i)
    print(results[i])
    print(coverages[i])
    print(averages_and_deviations[i])

# %%
results[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
    

results[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]


results[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 2, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 3, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 3, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 3, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 3, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.03259111103419188)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.028502714675268215, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.13075717833714784, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.03259111103419188)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 1, 0.8732745414252937, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
# checking unsafe [(0.4375, 0.5), (0.625, 0.6875)] ## took so long

results[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.29577906622244676)] = ["TO","TO"]


results[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 5, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.5057623641293089)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.028502714675268215, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.13075717833714784, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.03259111103419188)] = ["TO","TO"]

results[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
# checking unsafe [(0, 0.5), (0.5, 1)] current time is 2019-05-20 14:06:06.011982

results[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.5057623641293089)] = ["TO","TO"]
#checking unsafe [(0.6875, 0.75), (0.375, 0.5)] current time is 2019-05-20 15:50:12.307341

results[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
# checking unsafe [(0, 0.5), (0, 0.5)] current time is 2019-05-21 12:29:32.931795

results[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
# checking unsafe [(0, 0.5), (0, 0.5)] current time is 2019-05-21 15:29:48.598341
    
results[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
# checking unsafe [(0.5, 1), (0.5, 1)] current time is 2019-05-21 18:02:46.421406

results[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 100, 12, 1e-05, 10, 2, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 3500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 3500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 3500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8108008054929994)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.45223461506339047, 0.8440550299528644)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.03259111103419188)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.29577906622244676)] = ["TO","TO"]

results[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]
coverages[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]
averages_and_deviations[(0.95, 1500, 12, 1e-05, 10, 4, 0.6855555397734584, 0.8108008054929994)] = ["TO","TO"]

#results[()] = ["TO","TO"]
#coverages[()] = ["TO","TO"]
#averages_and_deviations[()] = ["TO","TO"]

# %%
# https://stackoverflow.com/questions/2020598/in-python-how-should-i-test-if-a-variable-is-none-true-or-false
def worker(region, constraints, intervals, n, epsilon, coverage, silent, version, size_q=False, debug=False):
    # queue.put(check_deeper(region, constraints, intervals, n, epsilon, coverage, silent, version, size_q=False, time_out=False, debug=False))   
    # print(ineq_to_constraints(constraints, intervals))
    a = check_deeper(region, ineq_to_constraints(constraints, intervals), n, epsilon, coverage, silent, version, size_q=False, debug=False).get_coverage()
    # print("file.write(str(a))", a)
    with open("coverage.txt","w") as file:
        file.write(str(a))

# %%
import datetime
count = 0
from multiprocessing import Process
try:
    os.remove("coverage.txt")
except:
    print()
now = datetime.datetime.now()
print("semisynchronous/synchronous")
for alpha in alphas:
    for n_samples in n_sampless:
        for N in populations:
            for depth in depths:
                for epsilon in epsilons:
                    for coverage_thresh in coverage_threshs:
                        for method in methods:
                            for v_p in p_values:
                                for v_q in q_values:
                                    count = count + 1
                                    print()
                                    print("************************************************************")
                                    print("alpha, n_samples, max_depth, min_rect_size, population, algorithm, v_p, v_q")
                                    print(f"{alpha}, {n_samples}, {depth}, {epsilon}, {N}, {method}, {v_p}, {v_q}")
                                    if (alpha, n_samples, depth, epsilon, N, method, v_p, v_q) in results.keys():
                                        print(f"times: {results[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)]}")
                                        continue

                                    ## INITIALISATION OF THE OUTPUT STRUCTURES
                                    runs = []
                                    results[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)] = []
                                    coverages[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)] = []

                                    ## RUN THE REFINEMENT
                                    print("Now computing, current time is: ", datetime.datetime.now())
                                    for run in range(0, sample_size):
                                        start_time = time()
                                        
                                        globals()["parameters"] = set()
                                        for polynome in f[N]:
                                            globals()["parameters"].update(find_param(polynome))
                                        globals()["parameters"] = sorted(list(globals()["parameters"]))
                                        parameters = globals()["parameters"]
                                        # print("parameters", parameters)
                                        # print(f[N])
                                        print(create_intervals(alpha, n_samples, D3[("synchronous_", N, n_samples, v_p, v_q)]))
                                        
                                        space = RefinedSpace([(0, 1), (0, 1)], parameters,["Real","Real"], [], [])
                                        # check_deeper(space, f[N], create_intervals(alpha, n_samples, D3[("synchronous_", N, n_samples, v_p, v_q)]), depth, epsilon, coverage_thresh, False, method)
                                        p = Process(target=worker, args=(space, f[N], create_intervals(alpha, n_samples, D3[("synchronous_", N, n_samples, v_p, v_q)]), depth, epsilon, coverage_thresh, False, method))
                                        # p.daemon = True
                                        p.start()
                                        p.join(7200)                                  

                                        if p.is_alive():
                                            print("TO passed")
                                            p.terminate()
                                            p.join()

                                            to = []
                                            for sample in range(sample_size):
                                                to.append("TO_2h")
                                            results[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)] = to
                                            coverages[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)] = to
                                            averages_and_deviations[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)] = to
                                            break

                                        with open("coverage.txt","r") as file:
                                            a = file.read()
                                            # print("file.read(): ",a)
                                            # print("file.read(): ",a[:-1])
                                            # print("type file.read(): ",type(a))
                                            coverage = float(a)
                                        # print("loaded coverage: ",coverage)
                                        
                                        time_foo = round(time() - start_time, 2)
                                        runs.append(time_foo)

                                        results[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)].append(str(time_foo))
                                        coverages[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q)].append(round(coverage, 4))
                                        os.remove("coverage.txt")
                                        
                                    ## COMPUTE AVERAGE RUN AND VARIATION
                                    if len(runs) > 0:
                                        average = sum(runs) / len(runs)
                                        deviations = []
                                        for run in range(0, sample_size):
                                            deviations.append((runs[run] - average) * (runs[run] - average))
                                        averages_and_deviations[(alpha, n_samples, depth, epsilon, N, method, v_p, v_q,)] = (average, math.sqrt(sum(deviations) / sample_size))

                                    ## PICKLE THE OUTPUT OF EXPERIMENTS WITH THIS SETTING SETTING
                                    pickle.dump(results, open("results.p", 'wb'))
                                    pickle.dump(coverages, open("coverages.p", 'wb'))
                                    pickle.dump(averages_and_deviations, open("averages_and_deviations.p", 'wb'))

# %%
count # 1200 = 1x3x1x1x4x4x5x5

# %%
results

# %%
for i in results.keys():
    if results[i] == ['hhh']:
        print(results[i])
        del results[i]
        del coverages[i]
        del averages_and_deviations[i]
        continue
    if results[i] == ['kkk']:
        print(results[i])
        del results[i]
        del coverages[i]
        del averages_and_deviations[i]
        continue
    if coverages[i] == [0]:
        print(i)
        print(results[i])
        print(coverages[i])
        print(averages_and_deviations[i])
        del results[i]
        del coverages[i]
        del averages_and_deviations[i]

# %%
coverages[0.95, 1500, 12, 1e-05, 2, 4, 0.13075717833714784, 0.29577906622244676]

# %%
for i in results.keys():
    if not results[i]:
        print(i)
        print(results[i])
        del results[i]

# %%
coverages[0.95, 3500, 12, 1e-05, 2, 4, 0.6855555397734584, 0.03259111103419188]

# %%
results = pickle.load(open("results.p","rb"))
coverages = pickle.load(open("coverages.p","rb"))
averages_and_deviations = pickle.load(open("averages_and_deviations.p","rb"))

# %%
import datetime
now = datetime.datetime.now()
outputfile="synthetise_performance_{}_{}.csv".format(now.isoformat().split(".")[0].replace(":","-"),socket.gethostname())
file = open(outputfile, "w")
file.write("semisynchronous/synchronous \n")
print("semisynchronous/synchronous")
file.write(" alpha, #n_samples, max_recursion_depth, min_rect_size, population, algorithm, v_p, v_q, run times{} average time, standard deviation\n".format(","*sample_size))
#file.write("---------------------------------------------------------------------------------------------------------\n")
print("alpha, n_samples, max_depth, min_rect_size , population, algorithm, v_p, v_q")
for alpha in alphas:
    for n_samples in n_sampless:
        for N in populations:
            for epsilon in epsilons:
                for depth in depths:
                    for coverage_thresh in coverage_threshs:                            
                        for method in methods:
                            for v_p in p_values:
                                for v_q in q_values:
                                    file.write(" {},   {},   {},       {},          {},             {},           {},          {},    ".format(alpha,n_samples,depth,epsilon,N,method,v_p,v_q))
                                    print(" {},    {},        {},        {},           {},         {},     {}, {}".format(alpha,n_samples,depth,epsilon,N,method,v_p,v_q))
                                    if (v_p,v_q,alpha,n_samples,depth,epsilon,N,method) in results.keys():
                                        for run in range(0,sample_size):
                                            file.write(results[(v_p,v_q,alpha,n_samples,depth,epsilon,N,method)][run])
                                            file.write(" (cov={}), ".format(coverages[(v_p,v_q,alpha,n_samples,depth,epsilon,N,method)][run]))
                                        file.write(" {},{}".format(averages_and_deviations[(v_p,v_q,alpha,n_samples,depth,epsilon,N,method)][0], averages_and_deviations[(v_p,v_q,alpha,n_samples,depth,epsilon,N,method)][1])) 
                                        file.write("\n")
                                        file.flush()
                                file.write("\n")
            #file.write("---------------------------------------------------------------------------------------------------------\n")
    #file.write("=========================================================================================================\n")
file.close()
